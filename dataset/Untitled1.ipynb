# %%
import requests

# %%
# !pip install beautifulsoup4

# %%
import bs4

# %%
# !pip install pandas numpy

# %%
import pandas as pd
import numpy as np

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
url = "https://www.google.com/travel/explore?tfs=CBwQAxopEgoyMDI1LTAxLTE1ag0IAhIJL20vMDM4NWs3cgwIBBIIL20vMDNyazBAAUgBcAGCAQsI____________AZgBArIBBBgBIAE&tfu=GgA&hl=en&gl=IN"
a = requests.get(url)
a
# Out:
# <Response [200]>

# %%
a.text
type(a.text)
# Out:
# str

# %%
from bs4 import BeautifulSoup

# %%
b = BeautifulSoup(a.text)
b
# Out:
# <!DOCTYPE html>
# ...

# %%
pip install google-flight-analysis
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ------------------------------ --------- 1.6/2.1 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 9.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from google_flight_analysis.scrape import *

# %%
# Assuming the Scrape class is defined elsewhere, and we want to access dates in the correct way

# Obtain your scrape object
result = Scrape('VGA', 'IST', '2023-07-20', '2023-08-20')  # Assume this gives us a valid object

# Check what attributes are available for the object
print(dir(result))

# If dates are stored as part of the query, we may need to use a different method/attribute
try:
    # Attempt to access the `dates` attribute directly
    print(result.dates)  # This might throw an error if the attribute doesn't exist
except AttributeError:
    # Handle the case where `dates` doesn't exist directly, maybe use a method like get_dates()
    print(f"Unable to access `dates` attribute directly. Available attributes: {dir(result)}")

# Alternatively, the `dates` might be accessible through a method or a different attribute
# Try another approach if there's a `get_dates()` method
if hasattr(result, 'get_dates'):
    print(result.get_dates())  # Use the method if it's available
else:
    # If `dates` is stored as part of the query, you might access it like this
    try:
        print(result.query['dates'])  # Example assuming dates are part of the query dictionary
    except KeyError:
        print("Dates are not part of the query.")
# Out:
# ['__add__', '__call__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_clean_results', '_data', '_date', '_dest', '_get_flight_elements', '_get_results', '_make_url', '_make_url_request', '_origin', '_scrape_data', '_set_properties', '_type', '_url', 'clone', 'combine', 'data', 'date', 'dest', 'origin', 'type', 'unpack', 'url']
# ...
